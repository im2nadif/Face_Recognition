# %% [markdown]
# ## Import Library

# %%
import os
import cv2
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Input
from keras.utils import to_categorical
from keras.layers import Conv2D, MaxPool2D, Flatten

# %% [markdown]
# ## Fungsi Progress Animation

# %%
def print_progress(val, val_len, folder, bar_size=20):
    progr = "#"*round((val)*bar_size/val_len) + " "*round((val_len - (val))*bar_size/val_len)
    if val == 0:
        print("", end = "\n")
    else:
        print("[%s] (%d samples)\t label : %s \t\t" % (progr, val+1, folder), end="\r")

# %% [markdown]
# ## Load Model Detection

# %%
from mtcnn_cv2 import MTCNN
detector_mtcnn = MTCNN()

# %%
from yoloface import face_analysis
face=face_analysis()
# Out:
# yolov3-tiny_face.weights:: status : file already exists
# yolov3_tiny_face.cfg:: status : file already exists
# face_detection.weights:: status : file already exists
# face_detection.cfg:: status : file already exists

# %%
face_cascade = cv2.CascadeClassifier('haarcascade/haarcascade_frontalface_default.xml')

# %% [markdown]
# ## Fungsi Face Detection

# %%
def detect_face_yolo(path):
    imgset = cv2.imread(path)
    imge,box,conf=face.face_detection(image_path=path,model='tiny')
    for (x, y, w, h) in box:
        img = imgset[y:y + w, x:x + h]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img, (50, 50))
        return img

# %%
def detect_face_haarcascade(img):
    face_img = img;
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    for (x, y, w, h) in faces:
        faces = img[y:y + h, x:x + w]
        imgx = cv2.cvtColor(faces, cv2.COLOR_BGR2GRAY)
        imgx = cv2.resize(imgx, (50, 50))
        return imgx

# %%
def detect_face_mtcnn(img):
    faces = detector_mtcnn.detect_faces(img)
    for face in faces:
        x, y, w, h = face['box']
        img = img[y:y + h, x:x + w]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img, (50, 50))
        return img

# %% [markdown]
# ## Fungsi Chart

# %%
def print_data(names):
    unique, counts = np.unique(names, return_counts = True)
    label_distr = {i:names.count(i) for i in names}.values()
    plt.figure(figsize=(12,6))
    my_circle = plt.Circle( (0,0), 0.7, color='white')
    plt.pie(label_distr, labels=unique, autopct='%1.1f%%')
    plt.gcf().gca().add_artist(my_circle)
    plt.show()
    for item in zip(unique, counts):
        print(item)

# %% [markdown]
# ## Fungsi Show Image Perbandingan Face Detection

# %%
def img_index(number):
    plt.rcParams["figure.figsize"] = [10.00, 3.50]
    plt.rcParams["figure.autolayout"] = False
    i1 = plt.subplot(1, 3, 1)
    i1.set_title("Haarcascade")
    plt.imshow(haar_images[number], cmap='gray')
    i2 = plt.subplot(1, 3, 2)
    i2.set_title("MTCNN")
    plt.imshow(mtcnn_images[number], cmap='gray')
    i3 = plt.subplot(1, 3, 3)
    i3.set_title("YOLO")
    plt.imshow(yolo_images[number], cmap='gray')
    plt.show()

# %% [markdown]
# ## Fungsi Balancing

# %%
def randc(labels, l):
    return np.random.choice(np.where(np.array(labels) == l)[0], n, replace=True)

yolo_bal = []
mtcnn_bal = []
yolo_bn = []
mtcnn_bn = []

def balancing(names, images, title):
    mask = np.hstack([randc(names, l) for l in np.unique(names)])
    names = [names[m] for m in mask]
    images = [images[m] for m in mask]
    if title == "MTCNN":    
        mtcnn_bal.extend(images)
        mtcnn_bn.extend(names)
    elif title == "YOLO":
        yolo_bal.extend(images)
        yolo_bn.extend(names)
        
    print('\n\n' + title)
    print_data(names)
    print("Jumlah Data " + title + " setelah Balancing : ", len(names))
    balance = len(names)

# %% [markdown]
# ## Fungsi Image Augmentation

# %%
def img_augmentation(img):
    h, w = img.shape
    center = (w // 2, h // 2)
    M_rot_5 = cv2.getRotationMatrix2D(center, 5, 1.0)
    M_rot_neg_5 = cv2.getRotationMatrix2D(center, -5, 1.0)
    M_rot_10 = cv2.getRotationMatrix2D(center, 10, 1.0)
    M_rot_neg_10 = cv2.getRotationMatrix2D(center, -10, 1.0)
    M_trans_3 = np.float32([[1, 0, 3], [0, 1, 0]])
    M_trans_neg_3 = np.float32([[1, 0, -3], [0, 1, 0]])
    M_trans_6 = np.float32([[1, 0, 6], [0, 1, 0]])
    M_trans_neg_6 = np.float32([[1, 0, -6], [0, 1, 0]])
    M_trans_y3 = np.float32([[1, 0, 0], [0, 1, 3]])
    M_trans_neg_y3 = np.float32([[1, 0, 0], [0, 1, -3]])
    M_trans_y6 = np.float32([[1, 0, 0], [0, 1, 6]])
    M_trans_neg_y6 = np.float32([[1, 0, 0], [0, 1, -6]])
    
    imgs = []
    imgs.append(cv2.warpAffine(img, M_rot_5, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_rot_neg_5, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_rot_10, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_rot_neg_10, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_trans_3, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_trans_neg_3, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_trans_6, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_trans_neg_6, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_trans_y3, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_trans_neg_y3, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_trans_y6, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.warpAffine(img, M_trans_neg_y6, (w, h), borderValue=(255,255,255)))
    imgs.append(cv2.add(img, 10))
    imgs.append(cv2.add(img, 30))
    imgs.append(cv2.add(img, -10))
    imgs.append(cv2.add(img, -30)) 
    imgs.append(cv2.add(img, 15))
    imgs.append(cv2.add(img, 45))
    imgs.append(cv2.add(img, -15))
    imgs.append(cv2.add(img, -45))
    
    return imgs

# %%
aug_img_mtcnn = []
aug_name_mtcnn = []

aug_img_yolo = []
aug_name_yolo = []

def augmented_data(images, names, title):
    print("Data Awal " + title + ":", len(ori_images))
    print("Data Balancing " + title + ":", len(names))
    
    augmented_images = []
    augmented_names = []

    for i, img in enumerate(images):
        try :
            augmented_images.extend(img_augmentation(img))
            augmented_names.extend([names[i]] * 20)
        except :
            print(i)
            
    if title == "YOLO":
        aug_img_yolo.extend(augmented_images)
        aug_name_yolo.extend(augmented_names)
    elif title == "MTCNN":
        aug_img_mtcnn.extend(augmented_images)
        aug_name_mtcnn.extend(augmented_names)
        
    print("Data Augmented " + title + ":", (len(augmented_images), len(augmented_names)))

# %% [markdown]
# ## Fungsi Load Dataset

# %%
dataset_folder = "dataset/"

yolo_names = []
yolo_images = []

mtcnn_names = []
mtcnn_images = []

haar_names = []
haar_images = []

ori_images = []
total = []

for folder in os.listdir(dataset_folder):
    files = os.listdir(os.path.join(dataset_folder, folder))[:150]
    if len(files) < 50 :
        continue
    for i, name in enumerate(files): 
        if name.find(".jpg") > -1 :
            imgs = cv2.imread(os.path.join(dataset_folder + folder, name))
            haar = detect_face_haarcascade(imgs)
            mtcn = detect_face_mtcnn(imgs)
            path = dataset_folder + folder + "/" + name
            yolo = detect_face_yolo(path)
            if haar is not None :
                haar_images.append(haar)
                haar_names.append(folder)
            if mtcn is not None :
                mtcnn_images.append(mtcn)
                mtcnn_names.append(folder)
            if yolo is not None :
                yolo_images.append(yolo)
                yolo_names.append(folder)
            if imgs is not None :
                print_progress(i, len(files), folder)
                ori_images.append(imgs)
                total.append(folder)
# Out:
# [####################] (77 samples)	 label : Ariel_Sharon
# [####################] (71 samples)	 label : Hugo_Chavez
# [####################] (73 samples)	 label : Ilham_Mafani_Nadif

# %%
print("Jumlah Dataset :", len(total))
# Out:
# Jumlah Dataset : 221

# %% [markdown]
# ## Face Detection

# %%
print("\n\nHAARCASCADE")
print_data(haar_names)

print("\n\nMTCNN")
print_data(mtcnn_names)

print("\n\nYOLO")
print_data(yolo_names)
# Out:
# HAARCASCADE
# ('Ariel_Sharon', 76)
# ('Hugo_Chavez', 71)
# ('Ilham_Mafani_Nadif', 52)
#
#
# MTCNN
# ('Ariel_Sharon', 72)
# ('Hugo_Chavez', 71)
# ('Ilham_Mafani_Nadif', 67)
#
#
# YOLO
# ('Ariel_Sharon', 77)
# ('Hugo_Chavez', 71)
# ('Ilham_Mafani_Nadif', 66)

# %% [markdown]
# ## Sample Face Detection

# %%
plt.imshow(ori_images[180], cmap='gray')
plt.show()

# %% [markdown]
# Gambar sebelum di lakukan deteksi wajah

# %%
img_index(180)

# %% [markdown]
# Hasil Cropping Image dengan 3 Model Deteksi Objek Wajah (Face Detection)

# %%
n = 66

# %%
balancing(mtcnn_names, mtcnn_images, "MTCNN")
balancing(yolo_names, yolo_images, "YOLO")
# Out:
# MTCNN
# ('Ariel_Sharon', 66)
# ('Hugo_Chavez', 66)
# ('Ilham_Mafani_Nadif', 66)
# Jumlah Data MTCNN setelah Balancing :  198
#
#
# YOLO
# ('Ariel_Sharon', 66)
# ('Hugo_Chavez', 66)
# ('Ilham_Mafani_Nadif', 66)
# Jumlah Data YOLO setelah Balancing :  198

# %%
img_test = yolo_bal[195]

augmented_image_test = img_augmentation(img_test)

plt.figure(figsize=(15,10))
for i, img in enumerate(augmented_image_test):
    plt.subplot(4,5,i+1)
    plt.imshow(img, cmap="gray")
plt.show()

# %%
augmented_data(mtcnn_bal, mtcnn_bn, "MTCNN")
# Out:
# Data Awal MTCNN: 221
# Data Balancing MTCNN: 198
# Data Augmented MTCNN: (3960, 3960)

# %%
augmented_data(yolo_bal, yolo_bn, "YOLO")
# Out:
# Data Awal YOLO: 221
# Data Balancing YOLO: 198
# Data Augmented YOLO: (3960, 3960)

# %%
img_test = aug_img_mtcnn[3959]

augmented_image_test = img_augmentation(img_test)

plt.figure(figsize=(15,10))
for i, img in enumerate(augmented_image_test):
    plt.subplot(4,5,i+1)
    plt.imshow(img, cmap="gray")
plt.show()

# %%
aug_name_mtcnn[3959]
# Out:
# 'Ilham_Mafani_Nadif'

# %%
def cnn_model(input_shape, labels):  
    model = Sequential()
    
    model.add(Conv2D(64,
                    (3,3),
                    padding="valid",
                    activation="relu",
                    input_shape=input_shape))
    
    model.add(Conv2D(64,
                    (3,3),
                    padding="valid",
                    activation="relu",
                    input_shape=input_shape))
    
    model.add(MaxPool2D(pool_size=(2, 2)))
    
    model.add(Conv2D(128,
                    (3,3),
                    padding="valid",
                    activation="relu"))
    model.add(Conv2D(128,
                    (3,3),
                    padding="valid",
                    activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    
    model.add(Dense(128, activation="relu"))
    model.add(Dense(64, activation="relu"))
    model.add(Dense(len(labels)))
    model.add(Activation("softmax"))
    
    model.summary() 
    
    model.compile(optimizer='adam', 
                  loss='categorical_crossentropy',
                  metrics = ['accuracy'])

    return model

# %%
le = LabelEncoder()
class Training:
    def __init__(self, names, images, title):
        self.name = names
        self.images = images     
        le.fit(names)
        labels = le.classes_
        name_vec = le.transform(names)
        categorical_name_vec = to_categorical(name_vec)
    
        x_train, x_test, y_train, y_test = train_test_split(np.array(images, dtype=np.float32),
                                                            np.array(categorical_name_vec),
                                                            test_size=0.15, 
                                                            random_state=42)
        
        x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
        x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
        
        self.xtrain = x_train
        self.xtest  = x_test
        self.ytrain = y_train
        self.ytest  = y_test
        self.label  = labels
        self.title  = title
    
    def xtest(self):
        return self.xtest
    
    def ytest(self):
        return self.ytest
    
    def label(self):
        return self.label
    
    def train_start(self):
        input_shape = self.xtrain[0].shape
        EPOCHS = 10
        BATCH_SIZE = 32
        model = cnn_model(input_shape, self.label)
        history = model.fit(self.xtrain, 
                            self.ytrain,
                            epochs=EPOCHS,
                            batch_size=BATCH_SIZE,
                            shuffle=True,
                            validation_split=0.15   # 15% dataset untuk testing/validasi
                            )
        self.history = history
        self.model = model
        
    def export_model(self):
        return self.model
    
    def evaluate_model(self):
        names = [['accuracy', 'val_accuracy'], 
                 ['loss', 'val_loss']]
        
        for name in names :
            fig1, ax_acc = plt.subplots()
            plt.plot(self.history.history[name[0]])
            plt.plot(self.history.history[name[1]])
            plt.xlabel('Epoch')
            plt.ylabel(name[0])
            plt.title('Model ' + self.title + ' - '+ name[0])
            plt.legend(['Training', 'Validation'], loc='lower right')
            plt.grid()
            plt.show()

# %%
mtcnn = Training(aug_name_mtcnn, aug_img_mtcnn, "MTCNN")
yolo  = Training(aug_name_yolo, aug_img_yolo, "YOLO")

# %%
un_mtcnn = Training(mtcnn_names, mtcnn_images, "MTCNN")
un_yolo  = Training(yolo_names, yolo_images, "YOLO")

# %%
mtcnn.train_start()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 48, 48, 64)        640
#
#  conv2d_5 (Conv2D)           (None, 46, 46, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 21, 21, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 19, 19, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 10368)             0
#
#  dense_3 (Dense)             (None, 128)               1327232
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 3)                 195
#
#  activation_1 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 1,594,691
# Trainable params: 1,594,691
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 90/90 [==============================] - 18s 195ms/step - loss: 1.9779 - accuracy: 0.6428 - val_loss: 0.2952 - val_accuracy: 0.9129
# Epoch 2/10
# 90/90 [==============================] - 19s 207ms/step - loss: 0.1645 - accuracy: 0.9458 - val_loss: 0.1717 - val_accuracy: 0.9505
# Epoch 3/10
# 90/90 [==============================] - 19s 210ms/step - loss: 0.0795 - accuracy: 0.9734 - val_loss: 0.0288 - val_accuracy: 0.9921
# Epoch 4/10
# 90/90 [==============================] - 18s 203ms/step - loss: 0.0656 - accuracy: 0.9808 - val_loss: 0.0251 - val_accuracy: 0.9941
# Epoch 5/10
# 90/90 [==============================] - 16s 183ms/step - loss: 0.0177 - accuracy: 0.9951 - val_loss: 0.0296 - val_accuracy: 0.9881
# Epoch 6/10
# 90/90 [==============================] - 17s 192ms/step - loss: 0.0620 - accuracy: 0.9815 - val_loss: 0.0317 - val_accuracy: 0.9901
# Epoch 7/10
# 90/90 [==============================] - 18s 204ms/step - loss: 0.0208 - accuracy: 0.9927 - val_loss: 0.0298 - val_accuracy: 0.9941
# Epoch 8/10
# 90/90 [==============================] - 16s 183ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0290 - val_accuracy: 0.9901
# Epoch 9/10
# 90/90 [==============================] - 17s 190ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0416 - val_accuracy: 0.9901
# Epoch 10/10
# 90/90 [==============================] - 16s 180ms/step - loss: 0.0164 - accuracy: 0.9941 - val_loss: 0.0039 - val_accuracy: 0.9980

# %%
yolo.train_start()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 48, 48, 64)        640
#
#  conv2d_9 (Conv2D)           (None, 46, 46, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 21, 21, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 19, 19, 128)       147584
#
#  max_pooling2d_5 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 10368)             0
#
#  dense_6 (Dense)             (None, 128)               1327232
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 3)                 195
#
#  activation_2 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 1,594,691
# Trainable params: 1,594,691
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 90/90 [==============================] - 17s 179ms/step - loss: 0.9539 - accuracy: 0.8413 - val_loss: 0.0494 - val_accuracy: 0.9881
# Epoch 2/10
# 90/90 [==============================] - 15s 170ms/step - loss: 0.0729 - accuracy: 0.9790 - val_loss: 0.0356 - val_accuracy: 0.9921
# Epoch 3/10
# 90/90 [==============================] - 15s 169ms/step - loss: 0.0358 - accuracy: 0.9906 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 4/10
# 90/90 [==============================] - 15s 168ms/step - loss: 0.0193 - accuracy: 0.9920 - val_loss: 0.0129 - val_accuracy: 0.9941
# Epoch 5/10
# 90/90 [==============================] - 15s 168ms/step - loss: 0.0166 - accuracy: 0.9955 - val_loss: 0.0157 - val_accuracy: 0.9941
# Epoch 6/10
# 90/90 [==============================] - 15s 168ms/step - loss: 0.0468 - accuracy: 0.9853 - val_loss: 0.0371 - val_accuracy: 0.9960
# Epoch 7/10
# 90/90 [==============================] - 15s 169ms/step - loss: 0.0179 - accuracy: 0.9934 - val_loss: 0.0069 - val_accuracy: 0.9980
# Epoch 8/10
# 90/90 [==============================] - 15s 168ms/step - loss: 0.0070 - accuracy: 0.9986 - val_loss: 0.0051 - val_accuracy: 0.9980
# Epoch 9/10
# 90/90 [==============================] - 15s 168ms/step - loss: 1.8791e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9980
# Epoch 10/10
# 90/90 [==============================] - 15s 168ms/step - loss: 1.0203e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9980

# %%
un_mtcnn.train_start()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 48, 48, 64)        640
#
#  conv2d_13 (Conv2D)          (None, 46, 46, 64)        36928
#
#  max_pooling2d_6 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 21, 21, 128)       73856
#
#  conv2d_15 (Conv2D)          (None, 19, 19, 128)       147584
#
#  max_pooling2d_7 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  flatten_3 (Flatten)         (None, 10368)             0
#
#  dense_9 (Dense)             (None, 128)               1327232
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 3)                 195
#
#  activation_3 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 1,594,691
# Trainable params: 1,594,691
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 5/5 [==============================] - 1s 192ms/step - loss: 14.4096 - accuracy: 0.3046 - val_loss: 1.9480 - val_accuracy: 0.4074
# Epoch 2/10
# 5/5 [==============================] - 1s 165ms/step - loss: 1.3599 - accuracy: 0.3444 - val_loss: 1.3144 - val_accuracy: 0.4074
# Epoch 3/10
# 5/5 [==============================] - 1s 162ms/step - loss: 1.1437 - accuracy: 0.3974 - val_loss: 1.0253 - val_accuracy: 0.4074
# Epoch 4/10
# 5/5 [==============================] - 1s 167ms/step - loss: 0.9932 - accuracy: 0.5099 - val_loss: 1.0221 - val_accuracy: 0.2963
# Epoch 5/10
# 5/5 [==============================] - 1s 163ms/step - loss: 0.8896 - accuracy: 0.5695 - val_loss: 0.7774 - val_accuracy: 0.6667
# Epoch 6/10
# 5/5 [==============================] - 1s 164ms/step - loss: 0.9243 - accuracy: 0.5563 - val_loss: 0.8646 - val_accuracy: 0.5926
# Epoch 7/10
# 5/5 [==============================] - 1s 164ms/step - loss: 0.6652 - accuracy: 0.7086 - val_loss: 0.8865 - val_accuracy: 0.6667
# Epoch 8/10
# 5/5 [==============================] - 1s 164ms/step - loss: 0.5952 - accuracy: 0.7881 - val_loss: 0.5020 - val_accuracy: 0.8519
# Epoch 9/10
# 5/5 [==============================] - 1s 164ms/step - loss: 0.4178 - accuracy: 0.9205 - val_loss: 0.6836 - val_accuracy: 0.7037
# Epoch 10/10
# 5/5 [==============================] - 1s 162ms/step - loss: 0.4099 - accuracy: 0.8344 - val_loss: 0.4221 - val_accuracy: 0.8148

# %%
un_yolo.train_start()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 48, 48, 64)        640
#
#  conv2d_17 (Conv2D)          (None, 46, 46, 64)        36928
#
#  max_pooling2d_8 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_18 (Conv2D)          (None, 21, 21, 128)       73856
#
#  conv2d_19 (Conv2D)          (None, 19, 19, 128)       147584
#
#  max_pooling2d_9 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  flatten_4 (Flatten)         (None, 10368)             0
#
#  dense_12 (Dense)            (None, 128)               1327232
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dense_14 (Dense)            (None, 3)                 195
#
#  activation_4 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 1,594,691
# Trainable params: 1,594,691
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 5/5 [==============================] - 1s 194ms/step - loss: 17.2562 - accuracy: 0.3007 - val_loss: 3.0164 - val_accuracy: 0.2500
# Epoch 2/10
# 5/5 [==============================] - 1s 165ms/step - loss: 1.7018 - accuracy: 0.3922 - val_loss: 1.1366 - val_accuracy: 0.2500
# Epoch 3/10
# 5/5 [==============================] - 1s 165ms/step - loss: 0.9382 - accuracy: 0.5621 - val_loss: 0.8132 - val_accuracy: 0.8214
# Epoch 4/10
# 5/5 [==============================] - 1s 164ms/step - loss: 0.6737 - accuracy: 0.7778 - val_loss: 0.4151 - val_accuracy: 0.7500
# Epoch 5/10
# 5/5 [==============================] - 1s 163ms/step - loss: 0.3726 - accuracy: 0.8497 - val_loss: 0.1542 - val_accuracy: 1.0000
# Epoch 6/10
# 5/5 [==============================] - 1s 164ms/step - loss: 0.2837 - accuracy: 0.8889 - val_loss: 0.2286 - val_accuracy: 0.8929
# Epoch 7/10
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1852 - accuracy: 0.9085 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0941 - accuracy: 0.9935 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0548 - accuracy: 0.9869 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0281 - accuracy: 0.9935 - val_loss: 0.0084 - val_accuracy: 1.0000

# %%
mtcnn.evaluate_model()
yolo.evaluate_model()

# %%
un_mtcnn.evaluate_model()
un_yolo.evaluate_model()

# %%
mtcnn.export_model().save("MTCN.h5")
yolo.export_model().save("YOLO.h5")
un_mtcnn.export_model().save("unMTCN.h5")
un_yolo.export_model().save("unYOLO.h5")

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(8, 8))
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
def conf(x_test, y_test, model, title, labels): 
    y_pred = model.predict(x_test)
    cnf_matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    np.set_printoptions(precision=2)
    print("\n\n")
    plot_confusion_matrix(cnf_matrix, classes=labels,normalize=False, title='Confusion Matrix ' + title)
    print(classification_report(y_test.argmax(axis=1), 
                            y_pred.argmax(axis=1), 
                            target_names=labels))

# %%
conf(mtcnn.xtest, mtcnn.ytest, mtcnn.export_model(), "MTCNN", mtcnn.label)
conf(yolo.xtest, yolo.ytest, yolo.export_model(), "YOLO", yolo.label)
conf(un_mtcnn.xtest, un_mtcnn.ytest, un_mtcnn.export_model(), "UN MTCNN", un_mtcnn.label)
conf(un_yolo.xtest, un_yolo.ytest, un_yolo.export_model(), "UNYOLO", un_yolo.label)
# Out:
# 19/19 [==============================] - 1s 34ms/step
#                     precision    recall  f1-score   support
#
#       Ariel_Sharon       0.99      1.00      1.00       216
#        Hugo_Chavez       1.00      0.98      0.99       208
# Ilham_Mafani_Nadif       0.99      1.00      0.99       170
#
#           accuracy                           0.99       594
#          macro avg       0.99      0.99      0.99       594
#       weighted avg       0.99      0.99      0.99       594
#
# 19/19 [==============================] - 1s 34ms/step
#                     precision    recall  f1-score   support
#
#       Ariel_Sharon       1.00      1.00      1.00       216
#        Hugo_Chavez       1.00      1.00      1.00       208
# Ilham_Mafani_Nadif       1.00      1.00      1.00       170
#
#           accuracy                           1.00       594
#          macro avg       1.00      1.00      1.00       594
#       weighted avg       1.00      1.00      1.00       594
#
# 1/1 [==============================] - 0s 92ms/step
#                     precision    recall  f1-score   support
#
#       Ariel_Sharon       0.69      0.90      0.78        10
#        Hugo_Chavez       1.00      0.50      0.67        10
# Ilham_Mafani_Nadif       0.86      1.00      0.92        12
#
#           accuracy                           0.81        32
#          macro avg       0.85      0.80      0.79        32
#       weighted avg       0.85      0.81      0.80        32
#
# 2/2 [==============================] - 0s 5ms/step
#                     precision    recall  f1-score   support
#
#       Ariel_Sharon       1.00      1.00      1.00        11
#        Hugo_Chavez       1.00      0.88      0.93         8
# Ilham_Mafani_Nadif       0.93      1.00      0.97        14
#
#           accuracy                           0.97        33
#          macro avg       0.98      0.96      0.97        33
#       weighted avg       0.97      0.97      0.97        33
